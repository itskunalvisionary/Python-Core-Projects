# %%
""" 
Goal:
✔ remove duplicates
✔ sort by resolution
✔ highest resolution choose

"""

# %%
res = [(720, "HD"), (1080, "FHD"), (480,"SD"), (720,"HD")]
unique = list(set(res))
unique.sort(reverse=True)


print("Available:", unique)
print("Best Resolution:", unique[0])
# Out:
# Available: [(1080, 'FHD'), (720, 'HD'), (480, 'SD')]
# Best Resolution: (1080, 'FHD')
