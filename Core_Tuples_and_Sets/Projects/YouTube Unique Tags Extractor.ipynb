# %%
"""    
Goal:

✔ Unique tags
✔ Sorted tags
✔ Count tags

"""

# %%
input = ["music","pop","music","dance","pop"]

unique_tags = tuple(input)
sorted_tags = sorted(unique_tags)
count_tags = len(unique_tags)

print(unique_tags)
print(sorted_tags)
print(count_tags)
# Out:
# ('music', 'pop', 'music', 'dance', 'pop')
# ['dance', 'music', 'music', 'pop', 'pop']
# 5
