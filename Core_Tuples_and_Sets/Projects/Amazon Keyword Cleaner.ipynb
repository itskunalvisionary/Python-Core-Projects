# %%
"""   
Goal:
✔ Remove duplicates
✔ Make lowercase
✔ Count unique keywords

"""

# %%
key = ("laptop","Laptop","laptop","LAPTOP")

clean = {k.lower() for k in key}
print(clean)
print("Unique Keywords:",len(key))
# Out:
# {'laptop'}
# Unique Keywords: 4
