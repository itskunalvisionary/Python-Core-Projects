# %%
def fraud_check(amount, location_change,hour):

    if amount > 75000:
        return "HIGH FRAUD RISK❗"
    
    if location_change:
        return "LOCATION MISMATCH📍"
    
    if hour <5:
        return "ODD HOUR TRANSACTION⌛😥"
    
    return "SAFE🦺"

print(fraud_check(20000,False,16))
# Out:
# SAFE🦺
