# %% [markdown]
# **Goal:**
#
# ✔ simulate "engagement heatmap"
# ✔ random 0–10 values
# ✔ 3x4 matrix
#
#
# likes
#
# saves
#
# reach
#
# shares

# %%
import random

rows, cols = 3, 4

for i in range(rows):
    for j in range(cols):
        print(random.randint(0, 11), end=" ")
    print()
# Out:
# 7 0 9 6
# 4 2 4 6
# 6 3 4 5
