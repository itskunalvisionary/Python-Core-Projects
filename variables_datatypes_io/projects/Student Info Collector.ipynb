# %%
# 1️⃣ Student Info Collector

# %%
name = input("enter your name: ").capitalize().strip()
age = int(input("enter your age: "))
grade = input("enter a grade: ").upper()

print(f"Name: {name} | Age: {age} | Grade: {grade}")
# Out:
# Name: Kunal | Age: 17 | Grade: A+
